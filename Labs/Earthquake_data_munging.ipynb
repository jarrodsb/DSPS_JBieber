# %% [markdown]
# <a href="https://colab.research.google.com/github/jarrodsb/DSPS_JBieber/blob/main/Labs/Earthquake_data_munging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Jarrod Bieber - PHYS 461

# %%
import pandas as pd

# %%
earthquakes = pd.read_csv("https://raw.githubusercontent.com/fedhere/DSPS_FBianco/refs/heads/main/data/earthquakes.csv", sep=r"\s+")

# %%
earthquakes.shape
# Out:
# (70798, 13)

# %%
earthquakes.head(7)
# Out:
#    #YYY/MM/DD  HH:mm:SS.ss  ET GT   MAG  M     LAT      LON  DEPTH  Q   EVID  \
# 0  1984/01/01  01:30:57.52  eq  l  2.02  c  33.246 -116.433    1.6  C  28255
# 1  1984/01/01  05:31:34.16  eq  l  2.12  c  32.945 -116.295    5.4  C  28259
# 2  1984/01/01  06:59:05.14  eq  l  2.43  c  33.343 -117.628    5.6  C  28260
# 3  1984/01/01  11:10:25.29  eq  l  2.07  c  33.668 -116.780   13.8  C  28270
# 4  1984/01/01  19:38:19.79  eq  l  2.13  c  33.963 -116.290    2.7  C  28553
# 5  1984/01/01  19:39:19.67  eq  l  2.13  c  34.062 -117.325   18.5  C  28282
# 6  1984/01/01  20:19:47.21  eq  l  2.02  c  35.180 -119.016   13.8  C  28284
#
#    NPH  NGRM
# 0   13    17
# 1   18    42
# 2   13    30
# 3   19    40
# 4   40    49
# 5   32    41
# 6   31    59

# %%
earthquakes.tail()
# Out:
#        #YYY/MM/DD  HH:mm:SS.ss  ET GT   MAG  M       LAT        LON  DEPTH  Q  \
# 70793  2002/12/29  19:37:24.56  eq  l  2.21  l  35.31400 -118.66767    3.7  A
# 70794  2002/12/29  20:17:33.40  eq  l  2.02  l  35.32133 -118.66000    1.8  A
# 70795  2002/12/29  20:21:28.73  eq  l  2.07  l  35.32150 -118.66617    1.9  A
# 70796  2002/12/30  21:51:52.55  eq  l  2.31  l  35.31867 -118.66250    1.5  A
# 70797  2002/12/30  23:38:49.79  eq  l  2.05  l  35.31450 -118.66333    1.9  A
#
#           EVID  NPH  NGRM
# 70793  9874709   25   948
# 70794  9874745   48   245
# 70795  9874749   53   277
# 70796  9875017   66   404
# 70797  9875061   54   283

# %%
earthquakes.columns
# Out:
# Index(['#YYY/MM/DD', 'HH:mm:SS.ss', 'ET', 'GT', 'MAG', 'M', 'LAT', 'LON',
#        'DEPTH', 'Q', 'EVID', 'NPH', 'NGRM'],
#       dtype='object')

# %%
earthquakes[['#YYY/MM/DD', 'HH:mm:SS.ss', "MAG"]]
# Out:
#        #YYY/MM/DD  HH:mm:SS.ss   MAG
# 0      1984/01/01  01:30:57.52  2.02
# 1      1984/01/01  05:31:34.16  2.12
# 2      1984/01/01  06:59:05.14  2.43
# 3      1984/01/01  11:10:25.29  2.07
# 4      1984/01/01  19:38:19.79  2.13
# ...           ...          ...   ...
# 70793  2002/12/29  19:37:24.56  2.21
# 70794  2002/12/29  20:17:33.40  2.02
# 70795  2002/12/29  20:21:28.73  2.07
# 70796  2002/12/30  21:51:52.55  2.31
# 70797  2002/12/30  23:38:49.79  2.05
#
# [70798 rows x 3 columns]

# %%
earthquakes.dtypes
# Out:
# #YYY/MM/DD      object
# HH:mm:SS.ss     object
# ET              object
# GT              object
# MAG            float64
# M               object
# LAT            float64
# LON            float64
# DEPTH          float64
# Q               object
# EVID             int64
# NPH              int64
# NGRM             int64
# dtype: object

# %%
mydictionary = {"v1": 0, "v2": 1}
mydictionary["v2"]
# Out:
# 1

# %%
earthquakes.rename({"#YYY/MM/DD": "date", "HH:mm:SS.ss": "time", "MAG": "mag"}, axis=1)
# Out:
#              date         time  ET GT   mag  M       LAT        LON  DEPTH  Q  \
# 0      1984/01/01  01:30:57.52  eq  l  2.02  c  33.24600 -116.43300    1.6  C
# 1      1984/01/01  05:31:34.16  eq  l  2.12  c  32.94500 -116.29500    5.4  C
# 2      1984/01/01  06:59:05.14  eq  l  2.43  c  33.34300 -117.62800    5.6  C
# 3      1984/01/01  11:10:25.29  eq  l  2.07  c  33.66800 -116.78000   13.8  C
# 4      1984/01/01  19:38:19.79  eq  l  2.13  c  33.96300 -116.29000    2.7  C
# ...           ...          ...  .. ..   ... ..       ...        ...    ... ..
# 70793  2002/12/29  19:37:24.56  eq  l  2.21  l  35.31400 -118.66767    3.7  A
# 70794  2002/12/29  20:17:33.40  eq  l  2.02  l  35.32133 -118.66000    1.8  A
# 70795  2002/12/29  20:21:28.73  eq  l  2.07  l  35.32150 -118.66617    1.9  A
# 70796  2002/12/30  21:51:52.55  eq  l  2.31  l  35.31867 -118.66250    1.5  A
# 70797  2002/12/30  23:38:49.79  eq  l  2.05  l  35.31450 -118.66333    1.9  A
#
#           EVID  NPH  NGRM
# ...

# %%
earthquakes
# Out:
#        #YYY/MM/DD  HH:mm:SS.ss  ET GT   MAG  M       LAT        LON  DEPTH  Q  \
# 0      1984/01/01  01:30:57.52  eq  l  2.02  c  33.24600 -116.43300    1.6  C
# 1      1984/01/01  05:31:34.16  eq  l  2.12  c  32.94500 -116.29500    5.4  C
# 2      1984/01/01  06:59:05.14  eq  l  2.43  c  33.34300 -117.62800    5.6  C
# 3      1984/01/01  11:10:25.29  eq  l  2.07  c  33.66800 -116.78000   13.8  C
# 4      1984/01/01  19:38:19.79  eq  l  2.13  c  33.96300 -116.29000    2.7  C
# ...           ...          ...  .. ..   ... ..       ...        ...    ... ..
# 70793  2002/12/29  19:37:24.56  eq  l  2.21  l  35.31400 -118.66767    3.7  A
# 70794  2002/12/29  20:17:33.40  eq  l  2.02  l  35.32133 -118.66000    1.8  A
# 70795  2002/12/29  20:21:28.73  eq  l  2.07  l  35.32150 -118.66617    1.9  A
# 70796  2002/12/30  21:51:52.55  eq  l  2.31  l  35.31867 -118.66250    1.5  A
# 70797  2002/12/30  23:38:49.79  eq  l  2.05  l  35.31450 -118.66333    1.9  A
#
#           EVID  NPH  NGRM
# ...

# %%
earthquakes = earthquakes.rename({"#YYY/MM/DD": "date", "HH:mm:SS.ss": "time", "MAG": "mag"}, axis=1)

# %%
earthquakes
# Out:
#              date         time  ET GT   mag  M       LAT        LON  DEPTH  Q  \
# 0      1984/01/01  01:30:57.52  eq  l  2.02  c  33.24600 -116.43300    1.6  C
# 1      1984/01/01  05:31:34.16  eq  l  2.12  c  32.94500 -116.29500    5.4  C
# 2      1984/01/01  06:59:05.14  eq  l  2.43  c  33.34300 -117.62800    5.6  C
# 3      1984/01/01  11:10:25.29  eq  l  2.07  c  33.66800 -116.78000   13.8  C
# 4      1984/01/01  19:38:19.79  eq  l  2.13  c  33.96300 -116.29000    2.7  C
# ...           ...          ...  .. ..   ... ..       ...        ...    ... ..
# 70793  2002/12/29  19:37:24.56  eq  l  2.21  l  35.31400 -118.66767    3.7  A
# 70794  2002/12/29  20:17:33.40  eq  l  2.02  l  35.32133 -118.66000    1.8  A
# 70795  2002/12/29  20:21:28.73  eq  l  2.07  l  35.32150 -118.66617    1.9  A
# 70796  2002/12/30  21:51:52.55  eq  l  2.31  l  35.31867 -118.66250    1.5  A
# 70797  2002/12/30  23:38:49.79  eq  l  2.05  l  35.31450 -118.66333    1.9  A
#
#           EVID  NPH  NGRM
# ...

# %%
earthquakes.describe()
# Out:
#                 mag           LAT          LON         DEPTH          EVID  \
# count  70798.000000  70798.000000  70798.00000  70798.000000  7.079800e+04
# mean       2.417826     33.977749   -116.88145      5.707677  3.699163e+06
# std        0.407683      1.156586      1.07667      3.842620  3.495378e+06
# min        2.000000     30.094830   -121.76000      0.000000  2.825500e+04
# 25%        2.120000     33.061000   -117.69200      3.100000  7.380962e+05
# 50%        2.300000     34.056750   -116.59000      5.300000  3.049477e+06
# 75%        2.590000     34.591000   -116.25100      6.900000  3.325926e+06
# max        7.100000     37.985500   -113.71900     29.300000  3.736673e+07
#
#                 NPH          NGRM
# count  70798.000000  70798.000000
# mean      30.424376    175.725049
# std       22.374143    226.196774
# min        0.000000      0.000000
# 25%       15.000000     59.000000
# 50%       24.000000    111.000000
# 75%       39.000000    211.000000
# ...

# %%
pd.to_datetime("2002/12/29" + " " + "19:37:24.56")
# Out:
# Timestamp('2002-12-29 19:37:24.560000')

# %%
earthquakes["newdate"] = earthquakes["date"].map(pd.to_datetime)

# %%
earthquakes["datetime"] = earthquakes["date"] + " " + earthquakes["time"]

# %%
earthquakes["newdatetime"] = earthquakes["datetime"].map(pd.to_datetime)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# parsing.pyx in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: second must be in 0..59
#
# The above exception was the direct cause of the following exception:
#
# DateParseError                            Traceback (most recent call last)
# /tmp/ipython-input-982549060.py in <cell line: 0>()
# ----> 1 earthquakes["newdatetime"] = earthquakes["datetime"].map(pd.to_datetime)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in map(self, arg, na_action)
#    4698         dtype: object
#    4699         """
# -> 4700         new_values = self._map_values(arg, na_action=na_action)
#    4701         return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4702             self, method="map"
#
# ...

# %%
for i in earthquakes.index:
  if earthquakes.loc[i, "time"].endswith('60.00'):
    print(earthquakes.loc[i, "time"])
    earthquakes.loc[i, "time"] = earthquakes.loc[i, "time"][:6] + "59.99"
    print(earthquakes.loc[i, "time"])

# %%
earthquakes["datetime"] = earthquakes["date"] + " " + earthquakes["time"]
earthquakes["newdatetime"] = earthquakes["datetime"].map(pd.to_datetime)

# %%
earthquakes["newdatetime"]
# Out:
# 0       1984-01-01 01:30:57.520
# 1       1984-01-01 05:31:34.160
# 2       1984-01-01 06:59:05.140
# 3       1984-01-01 11:10:25.290
# 4       1984-01-01 19:38:19.790
#                   ...
# 70793   2002-12-29 19:37:24.560
# 70794   2002-12-29 20:17:33.400
# 70795   2002-12-29 20:21:28.730
# 70796   2002-12-30 21:51:52.550
# 70797   2002-12-30 23:38:49.790
# Name: newdatetime, Length: 70798, dtype: datetime64[ns]

# %%
earthquakes.describe()
# Out:
#                 mag           LAT          LON         DEPTH          EVID  \
# count  70798.000000  70798.000000  70798.00000  70798.000000  7.079800e+04
# mean       2.417826     33.977749   -116.88145      5.707677  3.699163e+06
# min        2.000000     30.094830   -121.76000      0.000000  2.825500e+04
# 25%        2.120000     33.061000   -117.69200      3.100000  7.380962e+05
# 50%        2.300000     34.056750   -116.59000      5.300000  3.049477e+06
# 75%        2.590000     34.591000   -116.25100      6.900000  3.325926e+06
# max        7.100000     37.985500   -113.71900     29.300000  3.736673e+07
# std        0.407683      1.156586      1.07667      3.842620  3.495378e+06
#
#                 NPH          NGRM                        newdate  \
# count  70798.000000  70798.000000                          70798
# mean      30.424376    175.725049  1992-11-07 16:14:28.092318976
# min        0.000000      0.000000            1984-01-01 00:00:00
# ...

# %%
earthquakes["newdatetime"].mean()
# Out:
# Timestamp('1992-11-08 04:14:59.083973376')

# %%
earthquakes["newdatetime"].std()
# Out:
# Timedelta('1826 days 19:14:43.046994976')

# %%
earthquakes["newdatetime"].diff()
# Out:
# 0                          NaT
# 1       0 days 04:00:36.640000
# 2       0 days 01:27:30.980000
# 3       0 days 04:11:20.150000
# 4       0 days 08:27:54.500000
#                  ...
# 70793   0 days 00:00:30.140000
# 70794   0 days 00:40:08.840000
# 70795   0 days 00:03:55.330000
# 70796   1 days 01:30:23.820000
# 70797   0 days 01:46:57.240000
# Name: newdatetime, Length: 70798, dtype: timedelta64[ns]
